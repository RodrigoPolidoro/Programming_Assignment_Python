# %%
# Importing libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Read the outcome file into a character data frame 
outcome = pd.read_csv("outcome-of-care-measures.csv")

# %%
# Some analysis of the data frame
outcome.head()
# Out:
#   Provider Number                     Hospital Name  \
# 0          010001  SOUTHEAST ALABAMA MEDICAL CENTER
# 1          010005     MARSHALL MEDICAL CENTER SOUTH
# 2          010006    ELIZA COFFEE MEMORIAL HOSPITAL
# 3          010007          MIZELL MEMORIAL HOSPITAL
# 4          010008       CRENSHAW COMMUNITY HOSPITAL
#
#                     Address 1  Address 2  Address 3      City State  ZIP Code  \
# 0      1108 ROSS CLARK CIRCLE        NaN        NaN    DOTHAN    AL     36301
# 1  2505 U S HIGHWAY 431 NORTH        NaN        NaN      BOAZ    AL     35957
# 2          205 MARENGO STREET        NaN        NaN  FLORENCE    AL     35631
# 3               702 N MAIN ST        NaN        NaN       OPP    AL     36467
# 4         101 HOSPITAL CIRCLE        NaN        NaN   LUVERNE    AL     36049
#
#   County Name  Phone Number  ...  \
# 0     HOUSTON    3347938701  ...
# 1    MARSHALL    2565938310  ...
# 2  LAUDERDALE    2567688400  ...
# 3   COVINGTON    3344933541  ...
# ...

# %%
# Some analysis of the data frame
outcome.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4706 entries, 0 to 4705
# Data columns (total 46 columns):
#  #   Column                                                                                 Non-Null Count  Dtype
# ---  ------                                                                                 --------------  -----
#  0   Provider Number                                                                        4706 non-null   object
#  1   Hospital Name                                                                          4706 non-null   object
#  2   Address 1                                                                              4706 non-null   object
#  3   Address 2                                                                              0 non-null      float64
#  4   Address 3                                                                              0 non-null      float64
# ...

# %%
# Some analysis of the data frame
outcome.describe()
# Out:
#        Address 2  Address 3      ZIP Code  Phone Number
# count        0.0        0.0   4706.000000  4.706000e+03
# mean         NaN        NaN  53015.875691  5.827779e+09
# std          NaN        NaN  27054.121181  2.337224e+09
# min          NaN        NaN    603.000000  9.369338e+08
# 25%          NaN        NaN  32076.250000  3.613085e+09
# 50%          NaN        NaN  54238.000000  6.033435e+09
# 75%          NaN        NaN  75217.500000  7.877585e+09
# max          NaN        NaN  99901.000000  9.898943e+09

# %%
# Some analysis of the data frame
outcome.columns.tolist()
# Out:
# ['Provider Number',
#  'Hospital Name',
#  'Address 1',
#  'Address 2',
#  'Address 3',
#  'City',
#  'State',
#  'ZIP Code',
#  'County Name',
#  'Phone Number',
#  'Hospital 30-Day Death (Mortality) Rates from Heart Attack',
#  'Comparison to U.S. Rate - Hospital 30-Day Death (Mortality) Rates from Heart Attack',
#  'Lower Mortality Estimate - Hospital 30-Day Death (Mortality) Rates from Heart Attack',
#  'Upper Mortality Estimate - Hospital 30-Day Death (Mortality) Rates from Heart Attack',
#  'Number of Patients - Hospital 30-Day Death (Mortality) Rates from Heart Attack',
#  'Footnote - Hospital 30-Day Death (Mortality) Rates from Heart Attack',
#  'Hospital 30-Day Death (Mortality) Rates from Heart Failure',
#  'Comparison to U.S. Rate - Hospital 30-Day Death (Mortality) Rates from Heart Failure',
#  'Lower Mortality Estimate - Hospital 30-Day Death (Mortality) Rates from Heart Failure',
# ...

# %%
# Some analysis of the data frame
print("Number of rows", outcome.shape[0])
print("Number of columns", outcome.shape[1])
# Out:
# Number of rows 4706
# Number of columns 46

# %%
# Plot the 30 day mortality rates for heart attack
# Change the column to numeric values for plotting
outcome.iloc[:, 10] = pd.to_numeric(outcome.iloc[:, 10], errors = "coerce")

plt.hist( outcome.iloc[:, 10] )
# Out:
# (array([  9.,  46., 228., 638., 837., 627., 253.,  69.,  11.,   2.]),
#  array([10.1 , 11.28, 12.46, 13.64, 14.82, 16.  , 17.18, 18.36, 19.54,
#         20.72, 21.9 ]),
#  <BarContainer object of 10 artists>)
